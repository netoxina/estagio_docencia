% %% [markdown]
% # 1.3.1 - Lista de Exercícios (Transformadores)

% %% [markdown]
% # Aluno: Davi Carvalho Araújo

% %%
%% Solução Q1:

%% Item A:
% Corrente da fonte:
E = 120; % Volts
R = 8 % Ohms
Rt = 512 + R; % Ohms
If = E/Rt % A
% Potência Fornecida ao Alto-Falante:
P = (If^2)*R
% Out:
% R =  8
% If =  0.23077
% P =  0.42604

% %%
%% Solução Q1:

%% Item B:
Np = 8;
Ns = 1;
a = Np/Ns;
Zc = 8;
Zp = (a^2)*Zc % Ohm
% A Corrente da fonte é dada por:
R = 512;
Rt = 512 + R;
Is = E / Rt % Ampere
% Então a potência no primário que é igual à do secundário é:
P = (Is^2)*R % Watt
% Out:
% Zp =  512
% Is =  0.11719
% P =  7.0312

% %%
%% Solução Q1:

%% Item C:
% Comparando os valores obtidos nos itens A e B, temos que a potência obtida em B é cerca de 16x maior. 
% Ou seja, quando não usamos o transformador.

% %%
%% Solução Q2:

% Item A: Em condições ideais, a potência nos primários é igual à potência nos secundários e portanto a potência máxima ->
% -> fornecida pela fonte é de 40W.

% %%
%% Solução Q2:

% Item B:
% A potência no primário é:
Vp = 70.7; % Volt
Pp = 10; % Watt
Ip = Pp / Vp % Ampere
% logo, a resistência é:
Zp = Vp / Ip % Ohm
% Out:
% Ip =  0.14144
% Zp =  499.85

% %%
%% Solução Q2:

% Item C:
Zl = 8;
a = (Zp / Zl)^(1/2)
% Portanto, a proporção de praticamente 8:1.
% Out:
% a =  7.9045

% %%
%% Solução Q2:

% Item D:
Vs = Vc = Vp / a
% Out:
% Vs =  8.9443

% %%
%% Solução Q2:

% Item E:
% Já que todos os alto-falantes estão em paralelo, então:
% 1 alto-falante:
Rt1 = 500
% 2 alto-falantes:
Rt2 = 500/2
% 3 alto-falantes:
Rt3 = 500/3
% 4 alto-falantes:
Rt4 = 500/4
% Out:
% Rt1 =  500
% Rt2 =  250
% Rt3 =  166.67
% Rt4 =  125

% %%
%% Solução Q3:

% Item A:
a = 1 / 5;
Zl = 2;
Ip = 2;
Il = a * Ip % Ampere
Vl = Il * Zl % Volt

% Item B:
Zin = (a^2) * Zl % Ohm
% Out:
% Il =  0.40000
% Vl =  0.80000
% Zin =  0.080000

% %%
%% Solução Q13:

% Item A:
a = 4;
Rp = 4;
Rs = 1;
Re = Rp + ((a^2)*Rs)

% Item B:
Xp = 8;
Xs = 2;
Xe = Xp + ((a^2)*Xs)

% Item C:
Rl = 20;
Rd = (a^2)*Rl
% Não sei como realizar a representação.

% Item D:
Vg = 120;
Zp = 20 + 320 + 40j;
Ip = Vg / Zp

% Item E:
Vl = a * Ip * Rl
% Out:
% Re =  20
% Xe =  40
% Rd =  320
% Ip =  0.348123 - 0.040956i
% Vl =  27.8498 -  3.2765i

% %%
%% Solução Q8:

% Item A:
a = 8000/277;
Rp = 5;
Xp = 6;
Rpl = Rp / (a^2) % Ohm
Xpl = Xp / (a^2) % Ohm

Rc = 50000;
Xm = 10000;
Rcl = Rc / (a^2)
Xml = Xm / (a^2)
% Não sei como fazer a representação.
% Out:
% Rpl =  0.0059945
% Xpl =  0.0071933
% Rcl =  59.945
% Xml =  11.989

% %%
%% Solução Q8:

% Item B:
Vbase = 277;
Ibase = 100000 / 277;
Zbase = Vbase / Ibase
% Não sei como fazer a representação.

% Item C:
VR = ((283 - 277)/277)*100 % porcentagem

% Item D:
Pout = 100000 * 0.85 % Watt
Pcu = (361^2)*0.11
Pcore = (283^2)/50

% Item E:
n = (Pout / (Pout+Pcu+Pcore))*100 % porcentagem

% %%
%% Solução Q14: 

% Item A:
Np = 4;
Ns = 1;
a = Np / Ns
Rp = 4;
Rs = 1;
Xp = 8;
Xs = 2;
Re = Rp + (a^2)*Rs
Xe = Xp + (a^2)*Xs
Xl = 20;
Zp = Re + Xe + (a^2)*Xl

% Item B:
Vg = 120;
Ip = Vg / Zp
